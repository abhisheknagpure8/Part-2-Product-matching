# %% [markdown]
# <a href="https://colab.research.google.com/github/abhisheknagpure8/Part-2-Product-matching/blob/main/DS_Assignment_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing the required libraries and Data set

import pandas as pd
import numpy as np

# %%
amzn_df=pd.read_csv('/content/drive/MyDrive/Internshala Intership/amz_com-ecommerce_sample.csv',encoding='unicode_escape')
flip_df=pd.read_('/content/drive/MyDrive/Internshala Intership/flipkart_com-ecommerce_sample.csv',encoding='unicode_escape')

# %%
amzn_df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
# Describe the summary of the data set
amzn_df.describe()
# Out:
#         retail_price  discounted_price
# count   20000.000000       20000.00000
# mean     2957.095150        2364.59705
# std      8993.993257        8994.62368
# min       -20.000000           0.00000
# 25%       647.000000         424.00000
# 50%       999.000000         663.00000
# 75%      1986.000000        1235.00000
# max    571223.000000      726879.00000

# %%
#Checking the information and datatypes  
amzn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             20000 non-null  int64
#  7   discounted_price         20000 non-null  int64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
flip_df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
# Describe the summary of the data set
flip_df.describe()
# Out:
#         retail_price  discounted_price
# count   19922.000000      19922.000000
# mean     2979.206104       1973.401767
# std      9009.639341       7333.586040
# min        35.000000         35.000000
# 25%       666.000000        350.000000
# 50%      1040.000000        550.000000
# 75%      1999.000000        999.000000
# max    571230.000000     571230.000000

# %%
#Checking the information and datatypes  
flip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
#Retail_price and discounted_price columns are having null values in flipkart dataset.
#So we will find the rows contains null values and drop it in both datasets.

null_values = pd.isnull(flip_df['retail_price'])
flip_df[null_values]
# Out:
#                                 uniq_id            crawl_timestamp  \
# 12     c29af37837afcaf44b779eca7c19295f  2016-03-25 22:59:23 +0000
# 21     ea98a65ad1e1b8688eddf89fbc7b3e27  2016-03-25 22:59:23 +0000
# 76     64d5d4a258243731dc7bbb1eef49ad74  2016-04-30 03:22:56 +0000
# 812    39ed975091fd6d1d3ef3a7d33b8c4360  2016-01-06 18:20:45 +0000
# 1318   115ecd52f86ebf7a5509d0959a2caaa0  2016-03-25 15:39:25 +0000
# ...                                 ...                        ...
# 16762  43fbafdae704714c6543690161d3adb1  2015-12-20 08:26:17 +0000
# 17634  9d37d5a4ce327fb84cec4f56a2f0ac38  2016-05-22 10:35:27 +0000
# 19543  21c408cc5df0f78b3831ab1686c8dc68  2015-12-01 10:15:43 +0000
# 19599  c8db5fb95df382f7f5719609d0f02f80  2015-12-01 10:15:43 +0000
# 19622  950b6714a17d33211141fc4134ef1c5d  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 12     http://www.flipkart.com/sicons-all-purpose-tea...
# ...

# %%
#Dropping null values present in flip_df data and also in amzn_df data
flip_df[null_values].index
# Out:
# Int64Index([   12,    21,    76,   812,  1318,  1734,  2977,  3233,  3404,
#              3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
#              7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190,
#              8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
#             10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393,
#             11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
#             12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541,
#             12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
#             16487, 16762, 17634, 19543, 19599, 19622],
#            dtype='int64')

# %%
flip_df.drop([   12,    21,    76,   812,  1318,  1734,  2977,  3233,  3404,
             3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
             7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190,
             8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
            10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393,
            11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
            12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541,
            12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
            16487, 16762, 17634, 19543, 19599, 19622],axis=0,inplace=True)

# %%
amzn_df.drop([   12,    21,    76,   812,  1318,  1734,  2977,  3233,  3404,
             3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
             7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190,
             8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
            10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393,
            11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
            12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541,
            12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
            16487, 16762, 17634, 19543, 19599, 19622],axis=0,inplace=True)

# %%
#Retail and discounted price columns are in equal quantity now
#It will be now easy to compare from both dataset

flip_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19922 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  19922 non-null  object
#  1   crawl_timestamp          19922 non-null  object
#  2   product_url              19922 non-null  object
#  3   product_name             19922 non-null  object
#  4   product_category_tree    19922 non-null  object
#  5   pid                      19922 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19919 non-null  object
#  9   is_FK_Advantage_product  19922 non-null  bool
#  10  description              19920 non-null  object
#  11  product_rating           19922 non-null  object
#  12  overall_rating           19922 non-null  object
#  13  brand                    14071 non-null  object
# ...

# %%
amzn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19922 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  19922 non-null  object
#  1   crawl_timestamp          19922 non-null  object
#  2   product_url              19922 non-null  object
#  3   product_name             19922 non-null  object
#  4   product_category_tree    19922 non-null  object
#  5   pid                      19922 non-null  object
#  6   retail_price             19922 non-null  int64
#  7   discounted_price         19922 non-null  int64
#  8   image                    19919 non-null  object
#  9   is_FK_Advantage_product  19922 non-null  bool
#  10  description              19920 non-null  object
#  11  product_rating           19922 non-null  object
#  12  overall_rating           19922 non-null  object
#  13  brand                    14071 non-null  object
# ...

# %%
#Displaying product name of flip_df and amzn_df with counts
flip_df['product_name'].value_counts()
# Out:
# TheLostPuppy Back Cover for Apple iPad Air                            134
# TheLostPuppy Back Cover for Apple iPad Air 2                           95
# S4S Stylish Women's Push-up Bra                                        94
# Voylla Metal, Alloy Necklace                                           66
# WallDesign Small Vinyl Sticker                                         65
#                                                                      ...
# Radius Earbuds Radheadphones Hp-Rhf41P Headphones                       1
# Gioiabazar Book Cover for Samsung Galaxy Tab3 8.0" SM-T311 SM-T310      1
# snjmart C5 Ultra Dual Stereo Dynamic Earphone Wired Headphones          1
# Favourite BikerZ FBZ ROUND 9LED 61 Cast Iron Front Fog Lamp Unit        1
# Uberlyfe Extra Large Vinyl Sticker                                      1
# Name: product_name, Length: 12626, dtype: int64

# %%
amzn_df['product_name'].value_counts()
# Out:
# THELOSTPUPPY BACK COVER FOR APPLE IPAD AIR                                        141
# THELOSTPUPPY BACK COVER FOR APPLE IPAD AIR 2                                       95
# S4S Stylish Women's Push-up Bra                                                    94
# Voylla Metal, Alloy Necklace                                                       66
# HomeeHub Polyester Multicolor Self Design Eyelet Door Curtain                      58
#                                                                                  ...
# Indian Charm Multicolor Poth Beads Glass Necklace                                   1
# Netgear D1500                                                                       1
# Shopat7 Lady Bugs Cartoon Art Plastic Pencil Box                                    1
# Legrand Legrand Myrius 673018 6A White Push Button 6 One Way Electrical Switch      1
# UBERLYFE EXTRA LARGE VINYL STICKER                                                  1
# ...

# %%
#Fuzzy match two pandas dataframes based on one or more common fields
# !pip install fuzzymatcher
import fuzzymatcher
df=fuzzymatcher.fuzzy_left_join(amzn_df,flip_df,left_on='product_name',right_on='product_name')

# %%
df.head()
# Out:
#     best_match_score __id_left __id_right                      uniq_id_left  \
# 0           1.109848    0_left    0_right  c2d766ca982eca8304150849735ffef9
# 6           1.101432    1_left    1_right  7f7036a6d550aaa89d34c77bd39a5e48
# 10          0.511359    2_left    2_right  f449ec65dcbc041b6ae5e6a32717d01b
# 11          1.109848    3_left    0_right  0973b37acd0c664e3de26e97e5571454
# 17          1.485005    4_left    4_right  bc940ea42ee6bef5ac7cea3fb5cfbee7
#
#          crawl_timestamp_left  \
# 0   2016-03-25 22:59:23 +0000
# 6   2016-03-25 22:59:23 +0000
# 10  2016-03-25 22:59:23 +0000
# 11  2016-03-25 22:59:23 +0000
# 17  2016-03-25 22:59:23 +0000
#
#                                      product_url_left  \
# 0   http://www.flipkart.com/alisha-solid-women-s-c...
# 6   http://www.flipkart.com/fabhomedecor-fabric-do...
# 10  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 11  http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
#Dropping unnecessary columns
df=df.drop(columns=['best_match_score','__id_left','__id_right','uniq_id_left','crawl_timestamp_left','product_url_left','product_category_tree_left', 'pid_left', 'image_left', 'is_FK_Advantage_product_left',
       'description_left', 'product_rating_left', 'overall_rating_left',
       'brand_left', 'product_specifications_left', 'uniq_id_right',
       'crawl_timestamp_right', 'product_url_right',
       'product_category_tree_right', 'pid_right',
       'image_right',
       'is_FK_Advantage_product_right', 'description_right',
       'product_rating_right', 'overall_rating_right', 'brand_right',
       'product_specifications_right'])

# %%
#Required output
df
# Out:
#                               product_name_left  retail_price_left  \
# 0           Alisha Solid Women's Cycling Shorts                982
# 6           FabHomeDecor Fabric Double Sofa Bed              32143
# 10                                   AW Bellies                991
# 11          Alisha Solid Women's Cycling Shorts                694
# 17        Sicons All Purpose Arnica Dog Shampoo                208
# ...                                         ...                ...
# 150826           WALLDESIGN SMALL VINYL STICKER               1498
# 150876  WALLMANTRA LARGE VINYL STICKERS STICKER               1415
# 150926  ELITE COLLECTION MEDIUM ACRYLIC STICKER               1284
# 150954  ELITE COLLECTION MEDIUM ACRYLIC STICKER               1492
# 150982  ELITE COLLECTION MEDIUM ACRYLIC STICKER               1484
#
#         discounted_price_left                       product_name_right  \
# 0                         438      Alisha Solid Women's Cycling Shorts
# ...
